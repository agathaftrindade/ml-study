# %%
# !pip install mlcroissant
# !pip install pandas
# Out:
# Requirement already satisfied: mlcroissant in /opt/conda/lib/python3.11/site-packages (1.0.9)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.11/site-packages (from mlcroissant) (2.1.0)
# Requirement already satisfied: etils>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from etils[epath]>=1.7.0->mlcroissant) (1.9.4)
# Requirement already satisfied: jsonpath-rw in /opt/conda/lib/python3.11/site-packages (from mlcroissant) (1.4.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from mlcroissant) (3.3)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from mlcroissant) (2.2.3)
# Requirement already satisfied: pandas-stubs in /opt/conda/lib/python3.11/site-packages (from mlcroissant) (2.2.3.241009)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.11/site-packages (from mlcroissant) (2.9.0)
# Requirement already satisfied: rdflib in /opt/conda/lib/python3.11/site-packages (from mlcroissant) (7.0.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from mlcroissant) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from mlcroissant) (4.66.5)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from etils[epath]>=1.7.0->mlcroissant) (2024.9.0)
# Requirement already satisfied: importlib_resources in /opt/conda/lib/python3.11/site-packages (from etils[epath]>=1.7.0->mlcroissant) (6.4.5)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.11/site-packages (from etils[epath]>=1.7.0->mlcroissant) (4.12.2)
# Requirement already satisfied: zipp in /opt/conda/lib/python3.11/site-packages (from etils[epath]>=1.7.0->mlcroissant) (3.20.2)
# Requirement already satisfied: ply in /opt/conda/lib/python3.11/site-packages (from jsonpath-rw->mlcroissant) (3.11)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from jsonpath-rw->mlcroissant) (5.1.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from jsonpath-rw->mlcroissant) (1.16.0)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas->mlcroissant) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->mlcroissant) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->mlcroissant) (2024.2)
# Requirement already satisfied: types-pytz>=2022.1.1 in /opt/conda/lib/python3.11/site-packages (from pandas-stubs->mlcroissant) (2024.2.0.20241003)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from rdflib->mlcroissant) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from rdflib->mlcroissant) (3.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->mlcroissant) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->mlcroissant) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->mlcroissant) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->mlcroissant) (2024.8.30)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import mlcroissant as mlc
import pandas as pd
import string
from collections import OrderedDict
from sklearn.model_selection import train_test_split

# %%
# Fetch the Croissant JSON-LD
croissant_dataset = mlc.Dataset('https://www.kaggle.com/datasets/jackksoncsie/spam-email-dataset/croissant/download')

# Check what record sets are in the dataset
record_sets = croissant_dataset.metadata.record_sets
print(record_sets)

# Fetch the records and put them in a DataFrame
df = pd.DataFrame(croissant_dataset.records(record_set=record_sets[0].uuid))
df = df.rename(columns = {
    'emails.csv/text': 'body',
    'emails.csv/spam': 'is_spam'
})
df['body'] = df['body'].apply(lambda x: x.decode())
df['is_spam'] = df['is_spam'].apply(lambda x: False if x == 0 else True)
df
# Out:
# WARNING:absl:WARNING: The JSON-LD `@context` is not standard. Refer to the official @context (e.g., from the example datasets in https://github.com/mlcommons/croissant/tree/main/datasets/1.0). The different keys are: {'examples', 'rai'}
# WARNING:absl:Found the following 1 warning(s) during the validation:
#   -  [Metadata(Spam email Dataset)] Property "http://mlcommons.org/croissant/citeAs" is recommended, but does not exist.
# [RecordSet(uuid="emails.csv")]
#                                                    body  is_spam
# 0     Subject: naturally irresistible your corporate...     True
# 1     Subject: the stock trading gunslinger  fanny i...     True
# 2     Subject: unbelievable new homes made easy  im ...     True
# 3     Subject: 4 color printing special  request add...     True
# 4     Subject: do not have money , get software cds ...     True
# ...                                                 ...      ...
# 5723  Subject: re : research and development charges...    False
# 5724  Subject: re : receipts from visit  jim ,  than...    False
# 5725  Subject: re : enron case study update  wow ! a...    False
# 5726  Subject: re : interest  david ,  please , call...    False
# 5727  Subject: news : aurora 5 . 2 update  aurora ve...    False
#
# [5728 rows x 2 columns]

# %%
ham_count = df[df.is_spam == False].size
spam_count = df[df.is_spam == True].size

print(ham_count, spam_count)
# Out:
# 8720 2736

# %%
def clean_text(t):
    t = str.lower(t[8:])

    # filter non ascii characters
    t = ''.join(filter(lambda x: x in string.ascii_letters + ' ', t))

    # remove small words
    t = ' '.join(filter(lambda x: len(x) > 2, t.split()))    
    return t

def get_word_set(X):
    unique_words = {w for l in X for w in l.split()} 
    return unique_words

def count_words(text, known_words):
    t = clean_text(text)
    return set(t.split())

def count_words_list(texts, known_words):
    text_words = [w for row in texts for w in row.split()]
    return count_words(' '.join(text_words), known_words)

# %%
df['clean_body'] = df.body.apply(clean_text)
df.clean_body
# Out:
# 0       naturally irresistible your corporate identity...
# 1       the stock trading gunslinger fanny merrill but...
# 2       unbelievable new homes made easy wanting show ...
# 3       color printing special request additional info...
# 4       not have money get software cds from here soft...
#                               ...
# 5723    research and development charges gpg here forw...
# 5724    receipts from visit jim thanks again for the i...
# 5725    enron case study update wow all the same day t...
# 5726    interest david please call shirley crenshaw as...
# 5727    news aurora update aurora version the fastest ...
# Name: clean_body, Length: 5728, dtype: object

# %%
df.iloc[-1]
# Out:
# body          Subject: news : aurora 5 . 2 update  aurora ve...
# is_spam                                                   False
# clean_body    news aurora update aurora version the fastest ...
# Name: 5727, dtype: object

# %%
class BayesFilter():
    def __init__(self, c_threshold = 100):
        self.c_threshold = c_threshold
        
    def train(self, train_data):
        known_words = get_word_set(train_data.clean_body.to_list())

        ham_data = train_data[train_data.is_spam == False]
        X_ham = ham_data.clean_body

        spam_data = train_data[train_data.is_spam == True]
        X_spam = spam_data.clean_body

        # print(ham_data)

        
        self.ham_wbag = count_words_list(X_ham, known_words)
        self.spam_wbag = count_words_list(X_spam, known_words)
        
        self.prob_spam = spam_data.size / (spam_data.size + ham_data.size)
        
    def predict(self, body):
        body = clean_text(body)
        body_wordset = get_word_set([body])
        
        px_ham = len(set.intersection(body_wordset, self.ham_wbag)) / len(self.ham_wbag)
        px_spam = len(set.intersection(body_wordset, self.spam_wbag))  / len(self.spam_wbag)

        if px_ham == 0:
            px_ham = 0.001
        
        l1 = px_spam / px_ham
        l2 = self.prob_spam / (1 - self.prob_spam)      
        return l1 * l2 > self.c_threshold

    def __str__(self):
        return f'BayesFilter(c_threshold: {self.c_threshold}, prob_spam: {self.prob_spam})'

# %%
train_data, test_data = train_test_split(df, test_size = 0.3)

f = BayesFilter(0.42)
f.train(train_data)

str(f)
# Out:
# 'BayesFilter(c_threshold: 0.42, prob_spam: 0.23621850835619856)'

# %%
test_data['predict'] = test_data.clean_body.apply(f.predict)

test_successes = test_data[test_data.predict == test_data.is_spam]
test_errors = test_data[test_data.predict != test_data.is_spam]

accuracy = len(test_successes) / len(test_data)
false_positives = test_errors[test_errors.is_spam == True]
false_negatives = test_errors[test_errors.is_spam == False]

print(f'test_size: {len(test_data)}')
print(f'correctly predicted: {len(test_successes)}')
print()
print(f'accuracy: {accuracy}')
print(f'false_positives: {len(false_positives)}')
print(f'false_negatives: {len(false_negatives)}')
print()

test_data[['body', 'is_spam', 'predict']]
# Out:
# test_size: 1719
# correctly predicted: 1529
#
# accuracy: 0.8894706224549156
# false_positives: 2
# false_negatives: 188
#                                                    body  is_spam  predict
# 4789  Subject: correction : interim report to gary h...    False    False
# 2560  Subject: from the enron india newsdesk - may 5...    False    False
# 4934  Subject: thanks  hi keith !  thanks so much fo...    False     True
# 4042  Subject: re : spring 2001 schematic  kathy ,  ...    False    False
# 4139  Subject: credit model  vince and stinson ,  we...    False    False
# ...                                                 ...      ...      ...
# 2194  Subject: re : extreme value theory applied to ...    False    False
# 106   Subject: free 1 week dvd downloads  we are hap...     True     True
# 111   Subject: best prescription generic meds 4 less...     True     True
# 2170  Subject: re : mission impossible - hr associat...    False    False
# 3617  Subject: vol skew no - arbitrage constraints  ...    False    False
#
# [1719 rows x 3 columns]

# %%
f.spam_wbag - f.ham_wbag
# Out:
# {'summertime',
#  'bohsg',
#  'rafn',
#  'cadastrado',
#  'knoweledge',
#  'mausoleum',
#  'maubev',
#  'secondcategories',
#  'mort',
#  'biochemistry',
#  'harmonline',
#  'rechargeable',
#  'widest',
#  'christendom',
#  'superlative',
#  'sconce',
#  'reposio',
#  'goldschen',
#  'completo',
#  'lotsonet',
#  'alterman',
#  'allmerica',
#  'staccato',
#  'tribe',
#  'ochoa',
#  'slaughtered',
#  'prop',
#  'diapers',
#  'hcdc',
#  'seiected',
#  'horowitz',
#  'controleer',
#  'abnormality',
#  'decidedly',
#  'porous',
#  'quadrat',
#  'dastard',
#  'mentally',
#  'beep',
#  'shouid',
#  'unsatisfied',
#  'eurekahedge',
#  'letzte',
#  'engages',
#  'xana',
#  'alabi',
#  'limitation',
#  'patented',
#  'gastronomist',
#  'emile',
#  'nttpc',
#  'mainoemstore',
#  'olce',
#  'patriotic',
#  'raghallaigh',
#  'motorised',
#  'operateout',
#  'vaiuabie',
#  'grumbled',
#  'whoily',
#  'trauma',
#  'confiden',
#  'impartial',
#  'somatroph',
#  'alpan',
#  'spinnin',
#  'techncial',
#  'compliant',
#  'cultivable',
#  'mighty',
#  'phiri',
#  'urinary',
#  'caption',
#  'priceless',
#  'automaticaiiy',
#  'athlete',
#  'geography',
#  'inexpensively',
#  'pharmo',
#  'identities',
#  'diazge',
#  'jthomason',
#  'accumulation',
#  'fidir',
#  'erectionhealthier',
#  'nightclubs',
#  'ili',
#  'factory',
#  'spinfinder',
#  'purdue',
#  'spouting',
#  'westernsierramining',
#  'testimonial',
#  'gus',
#  'dlcations',
#  'labovitz',
#  'drowned',
#  'operandi',
#  'angry',
#  'deepscan',
#  'doesmatter',
#  'permafrost',
#  'cbxsales',
#  'movles',
#  'interel',
#  'yoursts',
#  'aba',
#  'catchy',
#  'overlaid',
#  'pelerine',
#  'unappreciative',
#  'envan',
#  'louisius',
#  'thiamin',
#  'een',
#  'pistil',
#  'iva',
#  'paludal',
#  'victims',
#  'nancee',
#  'ulcer',
#  'misery',
#  'soggier',
#  'authenticate',
#  'bybb',
#  'appiication',
#  'soar',
#  'systemworks',
#  'buik',
#  'isales',
#  'fbfb',
#  'canna',
#  'catalogers',
#  'cualesquiera',
#  'cosmetics',
#  'lessl',
#  'freezers',
#  'mhla',
#  'commtomm',
#  'yusuf',
#  'gioba',
#  'quantile',
#  'hiya',
#  'messagelabs',
#  'equipose',
#  'archives',
#  'deadpanpolitics',
#  'superink',
#  'optoelectronic',
#  'unbeiivable',
#  'leta',
#  'sandelli',
#  'havemore',
#  'cdz',
#  'nameand',
#  'voluntaryism',
#  'scsi',
#  'vvatches',
#  'mailpound',
#  'hefei',
#  'comforting',
#  'engrenagens',
#  'tscintroduced',
#  'scum',
#  'agreemeent',
#  'hvli',
#  'isnbank',
#  'ams',
#  'imm',
#  'dsl',
#  'aiias',
#  'bursts',
#  'popu',
#  'unspoilt',
#  'mais',
#  'ultima',
#  'primezone',
#  'dowlnoad',
#  'faveur',
#  'gratitude',
#  'noblewoman',
#  'prlc',
#  'aquisitions',
#  'realiy',
#  'clonus',
#  'allergies',
#  'fatima',
#  'minder',
#  'accredited',
#  'caucasus',
#  'wearing',
#  'unbeiivabie',
#  'teen',
#  'atheist',
#  'gryphon',
#  'ramble',
#  'ystyxapg',
#  'helpyou',
#  'shl',
#  'unliquidated',
#  'goneness',
#  'toraise',
#  'khalifa',
#  'thereare',
#  'dome',
#  'brovvse',
#  'sunscreen',
#  'cuboid',
#  'cctv',
#  'amid',
#  'ill',
#  'onboard',
#  'romanian',
#  'adrianbold',
#  'checkour',
#  'anotther',
#  'marquis',
#  'outdoor',
#  'includinq',
#  'ooffr',
#  'beggin',
#  'lookup',
#  'horseshoe',
#  'totale',
#  'seguenti',
#  'sunward',
#  'xiguan',
#  'micron',
#  'steeped',
#  'bouncehost',
#  'winstons',
#  'canoga',
#  'contient',
#  'astounding',
#  'philtre',
#  'rdh',
#  'yments',
#  'jerseys',
#  'outer',
#  'mcallen',
#  'cadger',
#  'extremists',
#  'fjt',
#  'visualbasic',
#  'orgasm',
#  'droichead',
#  'sartor',
#  'mywebdesignportfo',
#  'steroid',
#  'faarakxavoxcadetxjpir',
#  'emai',
#  'corpora',
#  'ulfclo',
#  'crohn',
#  'bioprojects',
#  'altercation',
#  'dirige',
#  'seu',
#  'genes',
#  'walaa',
#  'sons',
#  'youve',
#  'orte',
#  'alkaline',
#  'totaly',
#  'aine',
#  'milan',
#  'foundmy',
#  'bonjour',
#  'moira',
#  'availabie',
#  'bigs',
#  'rally',
#  'julho',
#  'deepti',
#  'internationalpromo',
#  'rhythm',
#  'obstructions',
#  'betrothal',
#  'buildinga',
#  'melville',
#  'unsubstantial',
#  'sprintpcs',
#  'adminder',
#  'headstone',
#  'iion',
#  'cashiers',
#  'monologues',
#  'blee',
#  'orderstatus',
#  'weary',
#  'meaningfully',
#  'offertory',
#  'versionsfeatures',
#  'bonefide',
#  'botox',
#  'quadrigae',
#  'medlca',
#  'putpeel',
#  'newtonian',
#  'dwell',
#  'dull',
#  'nowadays',
#  'rtd',
#  'decapitation',
#  'bvlgaries',
#  'jomsom',
#  'jodytotally',
#  'powwow',
#  'chieftain',
#  'criminal',
#  'leo',
#  'relatifs',
#  'supereva',
#  'blackleg',
#  'naughty',
#  'cryptography',
#  'mencionados',
#  'picturesque',
#  'kilometre',
#  'costco',
#  'oniy',
#  'paterae',
#  'amt',
#  'kenethmckenzie',
#  'vov',
#  'purree',
#  'unrecognized',
#  'johnne',
#  'vievv',
#  'vishnu',
#  'craven',
#  'lux',
#  'usb',
#  'idxo',
#  'blaspheme',
#  'saddlebow',
#  'urine',
#  'frankmullers',
#  'itt',
#  'stultification',
#  'thyroid',
#  'disrespectful',
#  'nasd',
#  'palace',
#  'bursary',
#  'surgical',
#  'furthest',
#  'oppers',
#  'jaxw',
#  'zonings',
#  'fied',
#  'nvda',
#  'exc',
#  'pharmace',
#  'ianguage',
#  'marilyn',
#  'nerveless',
#  'ondemand',
#  'soak',
#  'himalayas',
#  'pudenda',
#  'uncreated',
#  'clck',
#  'significantiy',
#  'presentable',
#  'iook',
#  'hungry',
#  'cylunj',
#  'coatee',
#  'overwhich',
#  'tarrock',
#  'wiil',
#  'arduous',
#  'grew',
#  'medio',
#  'shark',
#  'remarkable',
#  'amour',
#  'invests',
#  'zyban',
#  'polias',
#  'webslte',
#  'extracurricular',
#  'dsays',
#  'trophic',
#  'retdehola',
#  'corporal',
#  'conceit',
#  'historica',
#  'mailsthey',
#  'ultramweight',
#  'hmos',
#  'dhjommto',
#  'changeit',
#  'vvant',
#  'xenical',
#  'alarm',
#  'spacecraft',
#  'unpretending',
#  'hue',
#  'afflictions',
#  'quebre',
#  'enjoybestones',
#  'buiider',
#  'tatars',
#  'tentacle',
#  'vascular',
#  'gallipot',
#  'prion',
#  'thingamy',
#  'outlay',
#  'mariadacosta',
#  'daithi',
#  'unheard',
#  'entertaining',
#  'eventuate',
#  'makepretty',
#  'dose',
#  'imparti',
#  'perplexed',
#  'fontcolor',
#  'disturbed',
#  'confeccionamos',
#  'prostate',
#  'antilbkk',
#  'mxservers',
#  'unbuttoned',
#  'termites',
#  'kzll',
#  'fiberglass',
#  'mbertozzi',
#  'shelton',
#  'disposable',
#  'hackers',
#  'pntv',
#  'mittimus',
#  'pocketed',
#  'speciaiizes',
#  'yourname',
#  'meds',
#  'wilmont',
#  'negotiant',
#  'springfield',
#  'reciba',
#  'sailors',
#  'tossed',
#  'isoverwhelminq',
#  'ranker',
#  'dislodge',
#  'conning',
#  'vendas',
#  'wires',
#  'thick',
#  'towww',
#  'generics',
#  'conferm',
#  'unwanted',
#  'reformation',
#  'materia',
#  'cbc',
#  'aviod',
#  'mandalas',
#  'shingles',
#  'sta',
#  'sharuk',
#  'sma',
#  'contributeto',
#  'knot',
#  'lyndsey',
#  'nightly',
#  'catches',
#  'assassinat',
#  'kissimmee',
#  'seekercenter',
#  'oversold',
#  'ascending',
#  'interviewsemerging',
#  'alfonso',
#  'edad',
#  'amonqthe',
#  'ssi',
#  'expiosive',
#  'icensing',
#  'incurve',
#  'machinery',
#  'zaida',
#  'revnet',
#  'sculpt',
#  'dvertisers',
#  'geil',
#  'aerospace',
#  'prendre',
#  'bitterly',
#  'ouur',
#  'rrrhythms',
#  'contraption',
#  'stared',
#  'depressants',
#  'dispensation',
#  'imagination',
#  'venturing',
#  'weekdays',
#  'vain',
#  'insta',
#  'sensitiveness',
#  'errrection',
#  'developingand',
#  'pcb',
#  'winnipeg',
#  'sanches',
#  'inducement',
#  'obs',
#  'rubber',
#  'millwright',
#  'cavei',
#  'adversity',
#  'ptt',
#  'atlons',
#  'vpsc',
#  'nex',
#  'zongo',
#  'afore',
#  'intensified',
#  'uncover',
#  'attacked',
#  'listagem',
#  'melodramatic',
#  'greatt',
#  'huh',
#  'coalesce',
#  'uncut',
#  'centro',
#  'irreplaceable',
#  'daughter',
#  'dictatorship',
#  'defending',
#  'estockquest',
#  'seekers',
#  'pjwll',
#  'strychnine',
#  'pause',
#  'particles',
#  'broomcorn',
#  'marketingpractices',
#  'nely',
#  'bes',
#  'anagrafica',
#  'persona',
#  'baroda',
#  'augmentative',
#  'beloveth',
#  'sal',
#  'leaping',
#  'vaiuable',
#  'sesterce',
#  'refinanced',
#  'crews',
#  'venter',
#  'esteemed',
#  'moneyhon',
#  'ebay',
#  'scrubtheweb',
#  'dilatory',
#  'loosener',
#  'esaurito',
#  'disorder',
#  'cumshots',
#  'angels',
#  'bakken',
#  'tiscali',
#  'icelandic',
#  'extractor',
#  'maintenant',
#  'ralliedand',
#  'edible',
#  'sperm',
#  'confuse',
#  'ruining',
#  'blows',
#  'recordson',
#  'colloquialism',
#  'whichcontain',
#  'severetension',
#  'squirrelmail',
#  'msica',
#  'bannersgomlm',
#  'rayna',
#  'federation',
#  'lazy',
#  'leaps',
#  'startedto',
#  'cups',
#  'alter',
#  'potato',
#  'glacier',
#  'gunnison',
#  'compieted',
#  'loraforexmanaged',
#  'helaas',
#  'howit',
#  'sandisk',
#  'laziest',
#  'visible',
#  'novos',
#  'obeys',
#  'calmly',
#  'proposer',
#  'profitabie',
#  'berger',
#  'toegestaan',
#  'davina',
#  'recepiton',
#  'bloxz',
#  'themoney',
#  'menscare',
#  'succeeding',
#  'acrimony',
#  'receber',
#  'motors',
#  'celebst',
#  'genetics',
#  'loretha',
#  'oney',
#  'presentabie',
#  'lucio',
#  'fallow',
#  'resellers',
#  'honesty',
#  'unimpaired',
#  'amanda',
#  'sspltm',
#  'creatorstoll',
#  'lanquaqe',
#  'waist',
#  'shortest',
#  'qml',
#  'aicohol',
#  'secretive',
#  'allah',
#  'wellbeing',
#  'sparking',
#  'canonization',
#  'hypocrisy',
#  'morristown',
#  'shoreface',
#  'seil',
#  'ldupna',
#  'avfs',
#  'musket',
#  'burnished',
#  'hurley',
#  'winningstate',
#  'ineternet',
#  'fooled',
#  'implored',
#  'humble',
#  'overweight',
#  'cur',
#  'refin',
#  'andordered',
#  'technoiogy',
#  'kabila',
#  'operatic',
#  'preos',
#  'grading',
#  'toda',
#  'symbo',
#  'runyuan',
#  'tricks',
#  'aider',
#  'roddick',
#  'preventive',
#  'planners',
#  'topologize',
#  'vakantie',
#  'resonance',
#  'accesses',
#  'revoked',
#  'innocence',
#  'clique',
#  'bracelet',
#  'agnomen',
#  'mdc',
#  'compiiance',
#  'wrist',
#  'deux',
#  'willever',
#  'opps',
#  'bowed',
#  'asylum',
#  'heartedly',
#  'engrenagem',
#  'unhand',
#  'conspiracies',
#  'duo',
#  'surrejoinder',
#  'anglophobia',
#  'ifa',
#  'effectuation',
#  'gonna',
#  'omegas',
#  'walla',
#  'asgard',
#  'pioneering',
#  'wildest',
#  'sideways',
#  'sxjrohvneydjgucyfa',
#  'fixa',
#  'mobutu',
#  'gefilmt',
#  'onomatopoeia',
#  'aguardo',
#  'aaliyah',
#  'enquires',
#  'hotresponders',
#  'firenze',
#  'bacchic',
#  'reti',
#  'gal',
#  'substitution',
#  'sym',
#  'heliograph',
#  'viaspace',
#  'herpes',
#  'tercet',
#  'hilarious',
#  'datapest',
#  'swelled',
#  'usgs',
#  'acceso',
#  'ioqos',
#  'sshs',
#  'pinpointing',
#  'grundyism',
#  'ool',
#  'suqgestions',
#  'famtriptravel',
#  'vigoral',
#  'geek',
#  'ivan',
#  'herald',
#  'ibrk',
#  'reusable',
#  'interferes',
#  'cams',
#  'lovvprices',
#  'procmail',
#  'tical',
#  'removeme',
#  'complacent',
#  'guoding',
#  'cnnest',
#  'affordabowl',
#  'bedroom',
#  'winton',
#  'heirs',
#  'upheave',
#  'championship',
#  'gently',
#  'esatclear',
#  'sds',
#  'buechnerwww',
#  'remediable',
#  'dishing',
#  'simplythankyou',
#  'dieting',
#  'aloe',
#  'securitiesact',
#  'atocweddings',
#  'extranet',
#  'licencing',
#  'tits',
#  'occupation',
#  'suppiies',
#  'davidp',
#  'gperkes',
#  'dreamwaver',
#  'hiatal',
#  'inir',
#  'muiti',
#  'freexmovies',
#  'wbm',
#  'garry',
#  'molded',
#  'chheep',
#  'bello',
#  'madsen',
#  'derick',
#  'ofstimulating',
#  'lace',
#  'hacking',
#  'inspires',
#  'limitless',
#  'shtml',
#  'equa',
#  'paxil',
#  'omahahttp',
#  'phonetic',
#  'stickle',
#  'precautionary',
#  'bantus',
#  'grafics',
#  'conceive',
#  'beprocessed',
#  'repose',
#  'cyber',
#  'squezze',
#  'ject',
#  'reunions',
#  'cowards',
#  'vacancies',
#  'dentiaiity',
#  'odessa',
#  'awareness',
#  'quadrupie',
#  'motioned',
#  'shlppln',
#  'ncora',
#  'empilhadeira',
#  'dfvht',
#  'hon',
#  'medlc',
#  'wewill',
#  'fumigate',
#  'gerade',
#  'journey',
#  'powerfui',
#  'calendarlive',
#  'confidencial',
#  'upstart',
#  'tenants',
#  'whistleable',
#  'comwe',
#  'crothers',
#  'hovv',
#  'graand',
#  'biorhythm',
#  'ink',
#  'sese',
#  'redistribution',
#  'reliabie',
#  'orldwide',
#  'saludo',
#  'hpp',
#  'veryy',
#  'dion',
#  'toadminister',
#  'roi',
#  'vetting',
#  'iorefi',
#  'annemarie',
#  'tng',
#  'moshe',
#  'activation',
#  'pune',
#  'enviroline',
#  'willed',
#  'movers',
#  'employement',
#  'genome',
#  'dayservice',
#  'conceived',
#  'rhymes',
#  'groceries',
#  'bebf',
#  'neugierig',
#  'digraph',
#  'commentaryto',
#  'loser',
#  'andpossibly',
#  'pino',
#  'heeded',
#  'junho',
#  'runes',
#  'sockets',
#  'pickel',
#  'confiscate',
#  'magnetslip',
#  'betterof',
#  'grief',
#  'accumuiation',
#  'problams',
#  'gusmer',
#  'tussle',
#  'julio',
#  'jeramy',
#  'nigerian',
#  'sweet',
#  'diaper',
#  'ccheap',
#  'agrocom',
#  'afflicted',
#  'libertine',
#  'rahrah',
#  'choosefrom',
#  'tollgate',
#  'meta',
#  'motorola',
#  'burgeoning',
#  'thames',
#  'materialiy',
#  'uswith',
#  'emessaging',
#  'speedandlow',
#  'banian',
#  'finest',
#  'buds',
#  'clair',
#  'locales',
#  'buyonlinrmeds',
#  'ironfall',
#  'fertility',
#  'unscribe',
#  'biorhythms',
#  'resumption',
#  'pharmacies',
#  'escher',
#  'judiciary',
#  'anodrol',
#  'sex',
#  'onthis',
#  'clauura',
#  'commentaries',
#  'inhabit',
#  'unfold',
#  'hsbc',
#  'electrify',
#  'bma',
#  'xinlancenter',
#  'unpolitical',
#  'exactseek',
#  'guardsman',
#  'jturco',
#  'platinumadnetworks',
#  'adhesives',
#  'grummet',
#  'plainclothesman',
#  'alphabet',
#  'beforejuly',
#  'succe',
#  'nationals',
#  'frills',
#  'greasy',
#  'peopleyou',
#  'acelrate',
#  'extrusion',
#  'bootstrapped',
#  'ciphers',
#  'lotteries',
#  'kid',
#  'escalation',
#  'invasion',
#  'upfront',
#  'xilinx',
#  'subarctic',
#  'luminator',
#  'nasas',
#  'contactar',
#  'sprocketwheel',
#  'medzonli',
#  'juliana',
#  'tennesee',
#  'interflora',
#  'equipamentos',
#  'pomyslalam',
#  'suitcase',
#  'servicio',
#  'cumg',
#  'astraea',
#  'startinq',
#  'videos',
#  'angola',
#  'quaiit',
#  'monumental',
#  'basher',
#  'paysites',
#  'longest',
#  'cassia',
#  'youhave',
#  'spamassassin',
#  'invade',
#  'souhaite',
#  'yumhjn',
#  'outpatient',
#  'filiform',
#  'geologist',
#  'bent',
#  'thirteen',
#  'emerges',
#  'ironmail',
#  'clovis',
#  'ebook',
#  'ccnmatthews',
#  'shadow',
#  'virtuaily',
#  'quartz',
#  'makeover',
#  'jours',
#  'honolulu',
#  ...}
